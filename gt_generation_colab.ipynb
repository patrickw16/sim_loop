# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/esmini.zip /content/esmini.zip
# !unzip /content/esmini.zip
# Out:
# Archive:  /content/esmini.zip
#    creating: esmini/
#    creating: esmini/.git/
#    creating: esmini/.git/hooks/
#   inflating: esmini/.git/hooks/pre-receive.sample
#   inflating: esmini/.git/hooks/applypatch-msg.sample
#   inflating: esmini/.git/hooks/pre-push.sample
#   inflating: esmini/.git/hooks/prepare-commit-msg.sample
#   inflating: esmini/.git/hooks/fsmonitor-watchman.sample
#   inflating: esmini/.git/hooks/push-to-checkout.sample
#   inflating: esmini/.git/hooks/pre-rebase.sample
#   inflating: esmini/.git/hooks/post-update.sample
#   inflating: esmini/.git/hooks/pre-commit.sample
#   inflating: esmini/.git/hooks/update.sample
#   inflating: esmini/.git/hooks/pre-merge-commit.sample
#   inflating: esmini/.git/hooks/commit-msg.sample
#   inflating: esmini/.git/hooks/pre-applypatch.sample
#    creating: esmini/.git/info/
#   inflating: esmini/.git/info/exclude
#   inflating: esmini/.git/description
#    creating: esmini/.git/branches/
#    creating: esmini/.git/refs/
#    creating: esmini/.git/refs/heads/
#   inflating: esmini/.git/refs/heads/master
#    creating: esmini/.git/refs/tags/
#    creating: esmini/.git/refs/remotes/
#    creating: esmini/.git/refs/remotes/origin/
#   inflating: esmini/.git/refs/remotes/origin/HEAD
#   inflating: esmini/.git/index
#    creating: esmini/.git/objects/
#    creating: esmini/.git/objects/pack/
#   inflating: esmini/.git/objects/pack/pack-b0e74f112e037e56f65f6e6d5f7cf5d0c29c95af.pack
#   inflating: esmini/.git/objects/pack/pack-b0e74f112e037e56f65f6e6d5f7cf5d0c29c95af.idx
#    creating: esmini/.git/objects/info/
#   inflating: esmini/.git/packed-refs
#    creating: esmini/.git/logs/
#    creating: esmini/.git/logs/refs/
#    creating: esmini/.git/logs/refs/remotes/
#    creating: esmini/.git/logs/refs/remotes/origin/
#   inflating: esmini/.git/logs/refs/remotes/origin/HEAD
#    creating: esmini/.git/logs/refs/heads/
#   inflating: esmini/.git/logs/refs/heads/master
#   inflating: esmini/.git/logs/HEAD
#   inflating: esmini/.git/HEAD
#   inflating: esmini/.git/config
#    creating: esmini/.git/modules/
#    creating: esmini/.git/modules/externals/
#    creating: esmini/.git/modules/externals/fmi2/
#    creating: esmini/.git/modules/externals/fmi2/hooks/
#   inflating: esmini/.git/modules/externals/fmi2/hooks/pre-receive.sample
#   inflating: esmini/.git/modules/externals/fmi2/hooks/applypatch-msg.sample
#   inflating: esmini/.git/modules/externals/fmi2/hooks/pre-push.sample
#   inflating: esmini/.git/modules/externals/fmi2/hooks/prepare-commit-msg.sample
#   inflating: esmini/.git/modules/externals/fmi2/hooks/fsmonitor-watchman.sample
#   inflating: esmini/.git/modules/externals/fmi2/hooks/push-to-checkout.sample
#   inflating: esmini/.git/modules/externals/fmi2/hooks/pre-rebase.sample
#   inflating: esmini/.git/modules/externals/fmi2/hooks/post-update.sample
#   inflating: esmini/.git/modules/externals/fmi2/hooks/pre-commit.sample
#   inflating: esmini/.git/modules/externals/fmi2/hooks/update.sample
#   inflating: esmini/.git/modules/externals/fmi2/hooks/pre-merge-commit.sample
#   inflating: esmini/.git/modules/externals/fmi2/hooks/commit-msg.sample
#   inflating: esmini/.git/modules/externals/fmi2/hooks/pre-applypatch.sample
#    creating: esmini/.git/modules/externals/fmi2/info/
#   inflating: esmini/.git/modules/externals/fmi2/info/exclude
#   inflating: esmini/.git/modules/externals/fmi2/description
#    creating: esmini/.git/modules/externals/fmi2/branches/
#    creating: esmini/.git/modules/externals/fmi2/refs/
#    creating: esmini/.git/modules/externals/fmi2/refs/heads/
#   inflating: esmini/.git/modules/externals/fmi2/refs/heads/main
#    creating: esmini/.git/modules/externals/fmi2/refs/tags/
#    creating: esmini/.git/modules/externals/fmi2/refs/remotes/
#    creating: esmini/.git/modules/externals/fmi2/refs/remotes/origin/
#   inflating: esmini/.git/modules/externals/fmi2/refs/remotes/origin/HEAD
#    creating: esmini/.git/modules/externals/fmi2/objects/
#    creating: esmini/.git/modules/externals/fmi2/objects/pack/
#   inflating: esmini/.git/modules/externals/fmi2/objects/pack/pack-103f4e1d8052d8c2191d8310e3de11d06c64a7b4.pack
#   inflating: esmini/.git/modules/externals/fmi2/objects/pack/pack-103f4e1d8052d8c2191d8310e3de11d06c64a7b4.idx
#    creating: esmini/.git/modules/externals/fmi2/objects/info/
#   inflating: esmini/.git/modules/externals/fmi2/packed-refs
#    creating: esmini/.git/modules/externals/fmi2/logs/
#    creating: esmini/.git/modules/externals/fmi2/logs/refs/
#    creating: esmini/.git/modules/externals/fmi2/logs/refs/remotes/
#    creating: esmini/.git/modules/externals/fmi2/logs/refs/remotes/origin/
#   inflating: esmini/.git/modules/externals/fmi2/logs/refs/remotes/origin/HEAD
#    creating: esmini/.git/modules/externals/fmi2/logs/refs/heads/
#   inflating: esmini/.git/modules/externals/fmi2/logs/refs/heads/main
#   inflating: esmini/.git/modules/externals/fmi2/logs/HEAD
#   inflating: esmini/.git/modules/externals/fmi2/config
#   inflating: esmini/.git/modules/externals/fmi2/HEAD
#   inflating: esmini/.git/modules/externals/fmi2/index
#    creating: esmini/.git/modules/test/
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/index
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/config
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/hooks/
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/hooks/pre-receive.sample
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/hooks/applypatch-msg.sample
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/hooks/pre-push.sample
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/hooks/prepare-commit-msg.sample
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/hooks/fsmonitor-watchman.sample
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/hooks/push-to-checkout.sample
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/hooks/pre-rebase.sample
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/hooks/post-update.sample
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/hooks/pre-commit.sample
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/hooks/update.sample
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/hooks/pre-merge-commit.sample
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/hooks/commit-msg.sample
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/hooks/pre-applypatch.sample
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/info/
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/info/exclude
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/description
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/branches/
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/refs/
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/refs/heads/
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/refs/heads/master
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/refs/tags/
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/refs/remotes/
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/refs/remotes/origin/
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/refs/remotes/origin/HEAD
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/objects/
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/objects/pack/
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/objects/pack/pack-0273e4b8eb57b0d1a47b03f6f871612051782aa7.pack
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/objects/pack/pack-0273e4b8eb57b0d1a47b03f6f871612051782aa7.idx
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/objects/info/
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/packed-refs
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/logs/
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/logs/refs/
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/logs/refs/remotes/
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/logs/refs/remotes/origin/
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/logs/refs/remotes/origin/HEAD
#    creating: esmini/.git/modules/test/OSC-ALKS-scenarios/logs/refs/heads/
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/logs/refs/heads/master
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/logs/HEAD
#   inflating: esmini/.git/modules/test/OSC-ALKS-scenarios/HEAD
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/index
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/config
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/hooks/
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/hooks/pre-receive.sample
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/hooks/applypatch-msg.sample
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/hooks/pre-push.sample
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/hooks/prepare-commit-msg.sample
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/hooks/fsmonitor-watchman.sample
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/hooks/push-to-checkout.sample
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/hooks/pre-rebase.sample
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/hooks/post-update.sample
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/hooks/pre-commit.sample
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/hooks/update.sample
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/hooks/pre-merge-commit.sample
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/hooks/commit-msg.sample
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/hooks/pre-applypatch.sample
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/info/
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/info/exclude
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/description
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/branches/
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/refs/
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/refs/heads/
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/refs/heads/main
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/refs/tags/
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/refs/remotes/
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/refs/remotes/origin/
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/refs/remotes/origin/HEAD
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/objects/
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/objects/pack/
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/objects/pack/pack-3876e01c1cfde4834e3a3aa2bbf8b002c6344dea.pack
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/objects/pack/pack-3876e01c1cfde4834e3a3aa2bbf8b002c6344dea.idx
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/objects/info/
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/packed-refs
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/logs/
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/logs/refs/
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/logs/refs/remotes/
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/logs/refs/remotes/origin/
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/logs/refs/remotes/origin/HEAD
#    creating: esmini/.git/modules/test/OSC-NCAP-scenarios/logs/refs/heads/
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/logs/refs/heads/main
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/logs/HEAD
#   inflating: esmini/.git/modules/test/OSC-NCAP-scenarios/HEAD
#   inflating: esmini/.black-format
#   inflating: esmini/.clang-format
#   inflating: esmini/.clang-tidy
#   inflating: esmini/.cmake-format
#   inflating: esmini/.gitattributes
#    creating: esmini/.github/
#    creating: esmini/.github/actions/
#    creating: esmini/.github/actions/generate_offset_run_number/
#   inflating: esmini/.github/actions/generate_offset_run_number/action.yml
#    creating: esmini/.github/actions/setup_tools_shared/
#   inflating: esmini/.github/actions/setup_tools_shared/action.yml
#    creating: esmini/.github/actions/upload_esmini_artifacts/
#   inflating: esmini/.github/actions/upload_esmini_artifacts/action.yml
#    creating: esmini/.github/workflows/
#   inflating: esmini/.github/workflows/ci.yml
#   inflating: esmini/.github/workflows/sanitize.yml
#   inflating: esmini/.gitignore
#   inflating: esmini/.gitmodules
#    creating: esmini/3rd_party_terms_and_licenses/
#   inflating: esmini/3rd_party_terms_and_licenses/FBX_terms.txt
#   inflating: esmini/3rd_party_terms_and_licenses/JRC-FSM_LICENSE.txt
#   inflating: esmini/3rd_party_terms_and_licenses/OSC-ALKS-scenarios.txt
#   inflating: esmini/3rd_party_terms_and_licenses/OSC-NCAP-scenarios.txt
#   inflating: esmini/3rd_party_terms_and_licenses/OpenSceneGraph_LICENSE.txt
#   inflating: esmini/3rd_party_terms_and_licenses/OpenSimulationInterface-OSI_LICENSE.txt
#   inflating: esmini/3rd_party_terms_and_licenses/Protobuf_LICENSE.txt
#   inflating: esmini/3rd_party_terms_and_licenses/clothoids_LICENSE.txt
#   inflating: esmini/3rd_party_terms_and_licenses/dirent_LICENSE.txt
#   inflating: esmini/3rd_party_terms_and_licenses/expr_LICENSE.txt
#   inflating: esmini/3rd_party_terms_and_licenses/fmi_LICENSE.txt
#   inflating: esmini/3rd_party_terms_and_licenses/glfw_LICENSE.txt
#   inflating: esmini/3rd_party_terms_and_licenses/googletest_LICENSE.txt
#   inflating: esmini/3rd_party_terms_and_licenses/imgui_LICENSE.txt
#   inflating: esmini/3rd_party_terms_and_licenses/implot_LICENSE.txt
#   inflating: esmini/3rd_party_terms_and_licenses/links.txt
#   inflating: esmini/3rd_party_terms_and_licenses/odrSpiral_LICENCE.txt
#   inflating: esmini/3rd_party_terms_and_licenses/pugixml_LICENSE.txt
#   inflating: esmini/3rd_party_terms_and_licenses/sumo_LICENSE.txt
#   inflating: esmini/CMakeLists.txt
#   inflating: esmini/CMakePresets.json
#   inflating: esmini/CODEOWNERS
#   inflating: esmini/CONTRIBUTING.md
#    creating: esmini/EnvironmentSimulator/
#    creating: esmini/EnvironmentSimulator/Applications/
#    creating: esmini/EnvironmentSimulator/Applications/esmini-dyn/
#   inflating: esmini/EnvironmentSimulator/Applications/esmini-dyn/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/Applications/esmini-dyn/main.cpp
#    creating: esmini/EnvironmentSimulator/Applications/esmini/
#   inflating: esmini/EnvironmentSimulator/Applications/esmini/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/Applications/esmini/main.cpp
#    creating: esmini/EnvironmentSimulator/Applications/odrplot/
#   inflating: esmini/EnvironmentSimulator/Applications/odrplot/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/Applications/odrplot/main.cpp
#   inflating: esmini/EnvironmentSimulator/Applications/odrplot/xodr.py
#    creating: esmini/EnvironmentSimulator/Applications/odrviewer/
#   inflating: esmini/EnvironmentSimulator/Applications/odrviewer/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/Applications/odrviewer/example1.bat
#   inflating: esmini/EnvironmentSimulator/Applications/odrviewer/example2.bat
#   inflating: esmini/EnvironmentSimulator/Applications/odrviewer/example3.bat
#   inflating: esmini/EnvironmentSimulator/Applications/odrviewer/example4.bat
#   inflating: esmini/EnvironmentSimulator/Applications/odrviewer/example5.bat
#   inflating: esmini/EnvironmentSimulator/Applications/odrviewer/helpText.hpp
#   inflating: esmini/EnvironmentSimulator/Applications/odrviewer/main.cpp
#   inflating: esmini/EnvironmentSimulator/Applications/odrviewer/readme.txt
#    creating: esmini/EnvironmentSimulator/Applications/replayer/
#   inflating: esmini/EnvironmentSimulator/Applications/replayer/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/Applications/replayer/Replay.cpp
#   inflating: esmini/EnvironmentSimulator/Applications/replayer/Replay.hpp
#   inflating: esmini/EnvironmentSimulator/Applications/replayer/collision.hpp
#   inflating: esmini/EnvironmentSimulator/Applications/replayer/dat2csv.cpp
#   inflating: esmini/EnvironmentSimulator/Applications/replayer/helpText.hpp
#   inflating: esmini/EnvironmentSimulator/Applications/replayer/main.cpp
#   inflating: esmini/EnvironmentSimulator/Applications/replayer/osi_receiver.cpp
#   inflating: esmini/EnvironmentSimulator/Applications/replayer/readme.txt
#   inflating: esmini/EnvironmentSimulator/CMakeLists.txt
#    creating: esmini/EnvironmentSimulator/Libraries/
#    creating: esmini/EnvironmentSimulator/Libraries/esminiJS/
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiJS/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiJS/README.md
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiJS/build.sh
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiJS/embind.cpp
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiJS/esminijs.cpp
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiJS/esminijs.hpp
#    creating: esmini/EnvironmentSimulator/Libraries/esminiJS/example/
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiJS/example/index.html
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiJS/example/main.js
#    creating: esmini/EnvironmentSimulator/Libraries/esminiLib/
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiLib/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiLib/ESMiniWrapper.cs
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiLib/esminiLib.cpp
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiLib/esminiLib.hpp
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiLib/esminiUnityExample.cs
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiLib/helloWorld.cs
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiLib/simpleVehicleExample.cs
#    creating: esmini/EnvironmentSimulator/Libraries/esminiRMLib/
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiRMLib/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiRMLib/esminiRMLib.cpp
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiRMLib/esminiRMLib.hpp
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiRMLib/esminiRMUnityUtil.cs
#   inflating: esmini/EnvironmentSimulator/Libraries/esminiRMLib/esminiRMWrapper.cs
#    creating: esmini/EnvironmentSimulator/Modules/
#    creating: esmini/EnvironmentSimulator/Modules/CommonMini/
#   inflating: esmini/EnvironmentSimulator/Modules/CommonMini/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/Modules/CommonMini/CommonMini.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/CommonMini/CommonMini.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/CommonMini/UDP.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/CommonMini/UDP.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/CommonMini/version.cmake
#   inflating: esmini/EnvironmentSimulator/Modules/CommonMini/version.cpp.in
#   inflating: esmini/EnvironmentSimulator/Modules/CommonMini/version.cpp
#    creating: esmini/EnvironmentSimulator/Modules/Controllers/
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/Controller.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/Controller.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerACC.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerACC.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerALKS.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerALKS.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerALKS_R157SM.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerALKS_R157SM.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerECE_ALKS_RefDriver.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerECE_ALKS_RefDriver.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerExternal.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerExternal.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerFollowGhost.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerFollowGhost.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerFollowRoute.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerFollowRoute.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerInteractive.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerInteractive.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerLooming.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerLooming.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerOffroadFollower.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerOffroadFollower.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerRel2Abs.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerRel2Abs.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerSloppyDriver.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerSloppyDriver.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerSumo.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerSumo.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerUDPDriver.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/ControllerUDPDriver.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/vehicle.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/Controllers/vehicle.hpp
#    creating: esmini/EnvironmentSimulator/Modules/PlayerBase/
#   inflating: esmini/EnvironmentSimulator/Modules/PlayerBase/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/Modules/PlayerBase/PlayerServer.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/PlayerBase/PlayerServer.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/PlayerBase/Plot.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/PlayerBase/Plot.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/PlayerBase/helpText.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/PlayerBase/playerbase.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/PlayerBase/playerbase.hpp
#    creating: esmini/EnvironmentSimulator/Modules/RoadManager/
#   inflating: esmini/EnvironmentSimulator/Modules/RoadManager/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/Modules/RoadManager/LaneIndependentRouter.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/RoadManager/LaneIndependentRouter.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/RoadManager/RoadManager.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/RoadManager/RoadManager.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/RoadManager/odrSpiral.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/RoadManager/odrSpiral.h
#    creating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/CMakeLists.txt
#    creating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCAABBTree.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCAABBTree.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCBoundingBox.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCCommon.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCCondition.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCCondition.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCDirectory.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCFile.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCGlobalAction.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCGlobalAction.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCParameterDeclarations.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCParameterDistribution.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCParameterDistribution.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCPosition.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCPosition.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCPrivateAction.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCPrivateAction.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCProperties.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCSwarmTrafficGeometry.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCSwarmTrafficGeometry.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCTriangle2D.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/OSCTypeDefs/OSCUtils.hpp
#    creating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/Action.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/Action.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/Catalogs.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/Catalogs.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/Entities.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/Entities.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/IdealSensor.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/IdealSensor.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/OSIReporter.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/OSIReporter.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/OSITrafficCommand.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/OSITrafficCommand.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/Parameters.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/Parameters.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/RoadNetwork.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/RoadNetwork.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/ScenarioEngine.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/ScenarioEngine.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/ScenarioGateway.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/ScenarioGateway.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/ScenarioReader.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/ScenarioReader.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/Server.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/Server.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/Storyboard.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/Storyboard.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/StoryboardElement.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/StoryboardElement.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/simple_expr.c
#   inflating: esmini/EnvironmentSimulator/Modules/ScenarioEngine/SourceFiles/simple_expr.h
#    creating: esmini/EnvironmentSimulator/Modules/ViewerBase/
#   inflating: esmini/EnvironmentSimulator/Modules/ViewerBase/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/Modules/ViewerBase/OSISensorView.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ViewerBase/OSISensorView.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ViewerBase/RubberbandManipulator.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ViewerBase/RubberbandManipulator.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ViewerBase/roadgeom.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ViewerBase/roadgeom.hpp
#   inflating: esmini/EnvironmentSimulator/Modules/ViewerBase/viewer.cpp
#   inflating: esmini/EnvironmentSimulator/Modules/ViewerBase/viewer.hpp
#    creating: esmini/EnvironmentSimulator/Unittest/
#   inflating: esmini/EnvironmentSimulator/Unittest/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/Unittest/CommonMini_test.cpp
#   inflating: esmini/EnvironmentSimulator/Unittest/FollowRouteController_test.cpp
#   inflating: esmini/EnvironmentSimulator/Unittest/FollowRoute_test.cpp
#   inflating: esmini/EnvironmentSimulator/Unittest/OperatingSystem_test.cpp
#   inflating: esmini/EnvironmentSimulator/Unittest/RoadManagerDll_test.cpp
#   inflating: esmini/EnvironmentSimulator/Unittest/RoadManager_test.cpp
#   inflating: esmini/EnvironmentSimulator/Unittest/ScenarioEngineDll_test.cpp
#   inflating: esmini/EnvironmentSimulator/Unittest/ScenarioEngine_test.cpp
#   inflating: esmini/EnvironmentSimulator/Unittest/ScenarioPlayer_test.cpp
#    creating: esmini/EnvironmentSimulator/Unittest/xodr/
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/Junction_with_building0.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/Weird_looking_building_local_coord.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/Weird_looking_building_road_coord.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/circular_road.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/consecutive_roads.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/curve_road_mixed.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/direct_junction_simple.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/explicit_line.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/fabriksgatan_mixed_id_types.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/highway_example_with_merge_and_split.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/highway_exit.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/highway_intersection_test0.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/highway_merge.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/highway_split.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/highway_split_lht.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/mixed_roads.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/multi_intersections.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/multi_intersections_changed_speeds.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/multi_lane_3way_intersection.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/multi_lanesections.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/mw_100m.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/oppositeLaneRoad.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/ref_point.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/road_straight_curve_junction.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/route_strategy_test_road.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/route_strategy_test_road_LHT.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/simple_3way_intersection.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/simple_3way_intersection_lht.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/simple_3way_motorway.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/simple_4way_intersection.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/simple_highway.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/slope_up_leaning_right.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/slope_up_slope_down.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/some_signs.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/star.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/straight_20m.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/straight_2x100m_opposite.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/straight_3000m.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/straight_500_superelevation_elevation.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/straight_500_superelevation_elevation_curve.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/straight_highway_500m.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/straight_road.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/timing_scenario0.xodr
#   inflating: esmini/EnvironmentSimulator/Unittest/xodr/two_roads_overhang.xodr
#    creating: esmini/EnvironmentSimulator/Unittest/xosc/
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/Junction_with_building0.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/VehiclePropertyTest.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/Weird_looking_building_local_coord.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/Weird_looking_building_road_coord.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/acc_with_interactive_steering.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/add_delete_entity.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/alks_r157_quick_stop_test.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/alks_r157_test.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/bike_tilt_smooth.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/brake_by_trajectory_100-0.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/circular_road.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/conflicting-domains.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/consecutive_roads.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/curve_slope_simple.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/direct_junction.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/direction_dimension_demo.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/direction_dimension_trig.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/distance_with_trailers.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/dummy_mw.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/elevations.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/emergency_vehicle.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/follow_ghost_align_position.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/follow_route_blocked_by_collision_risk.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/follow_route_collision_risk.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/follow_route_controller_test_medium.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/follow_route_multiple_scenario_waypoints.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/follow_route_no_path.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/follow_route_set_parameters.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/follow_route_with_lane_change.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/follow_trajectory_reverse.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/four_roads.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/friction_and_lane_change_edge_case.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/full_e6mini.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/full_e6mini_reverse.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/ghost_restart.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/ghost_restart2.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/ghost_route.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/highway_exit.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/highway_exit_with_route.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/highway_intersection_test0.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/highway_merge.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/highway_split.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/highway_split_lht.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/init_test.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/init_test_objects_strange_order.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/instant_lane_change.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/junction-selector.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/lane_change_friction.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/lane_change_trig_by_variable.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/lateral_maneuvers_test.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/loomingAdvancedTest.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/loomingHW.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/loomingTest.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/maneuver_groups_x_3.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/miscobj_basic.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/multi_controller.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/multi_lane_changes.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/multi_lanesections.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/multilane_3way_intersection_osi.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/override_action.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/override_action_with_group_type.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/perform_single_lane_change.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/position_types.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/positioning_slope_up_leaning_right.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/ref_point.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/relative_clearance_freeSpace.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/relative_clearance_oppositLane.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/relative_lane_change.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/relative_lane_offset.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/relative_lane_pos_offset_trajectories.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/relative_lane_pos_trajectories.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/relative_pos_over_intersection.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/relative_speed_phases.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/repeated_relative_speed.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/reverse_lane_change.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/rising_edge.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/route_detour.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/route_lane_change.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/sign_test.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/simple_3_way_intersection_osi.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/simple_3_way_intersection_osi_lht.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/simple_4_way_intersection_osi.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/simple_motorway_osi_intersection.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/slope_up_slope_down.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/speed-profile_test.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/speed_over_distance.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/star.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/star_position_types.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/sudden_teleport.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/test-collision-detection.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/test_action_dynamics.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/test_elevation_mapping.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/test_string_ids.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/timing_scenario0.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/timing_scenario_with_restarts.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/traj-heading-trig.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/trajectory-continuity.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/ttc_condition.xosc
#   inflating: esmini/EnvironmentSimulator/Unittest/xosc/user_defined_action.xosc
#    creating: esmini/EnvironmentSimulator/code-examples/
#   inflating: esmini/EnvironmentSimulator/code-examples/CMakeLists.txt
#    creating: esmini/EnvironmentSimulator/code-examples/access-odr/
#   inflating: esmini/EnvironmentSimulator/code-examples/access-odr/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/code-examples/access-odr/access-odr.cpp
#    creating: esmini/EnvironmentSimulator/code-examples/ad_hoc_traffic/
#   inflating: esmini/EnvironmentSimulator/code-examples/ad_hoc_traffic/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/code-examples/ad_hoc_traffic/ad_hoc_traffic.cpp
#   inflating: esmini/EnvironmentSimulator/code-examples/ad_hoc_traffic/ad_hoc_traffic.py
#   inflating: esmini/EnvironmentSimulator/code-examples/ad_hoc_traffic/empty_scenario.xosc
#    creating: esmini/EnvironmentSimulator/code-examples/convert_position_type/
#   inflating: esmini/EnvironmentSimulator/code-examples/convert_position_type/manipulate_positions.py
#   inflating: esmini/EnvironmentSimulator/code-examples/convert_position_type/print_positions.py
#    creating: esmini/EnvironmentSimulator/code-examples/hello_world/
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/output.png
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/log.txt
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/acc_with_external_controller.xosc
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/action_injection.cpp
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/action_injection.py
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/add_sensor.py
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/change_speed.py
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/drive.py
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/dual_controllers.cpp
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/forward_cmd_args.py
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/get_states.py
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/hw2_arguments.cpp
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/hw3_fetch_states.cpp
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/hw4_external_ego_control.cpp
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/hw5_control_controllers_enabled.cpp
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/hw6_control_controllers_disabled.cpp
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/hw7_ideal_sensors.cpp
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/hw8_collision_detection.cpp
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/init_by_args.py
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/inject_actions_udp.py
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/object_callback.py
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/osi_groundtruth.py
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/osi_groundtruth_from_udp.py
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/speed_controller.cpp
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/speed_controller.py
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/storyboard_state_callback.py
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world/use_roadmanager.py
#    creating: esmini/EnvironmentSimulator/code-examples/hello_world_static/
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world_static/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/code-examples/hello_world_static/hello_world_static.cpp
#    creating: esmini/EnvironmentSimulator/code-examples/ideal-sensors/
#   inflating: esmini/EnvironmentSimulator/code-examples/ideal-sensors/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/code-examples/ideal-sensors/ideal-sensors.cpp
#    creating: esmini/EnvironmentSimulator/code-examples/image-capture/
#   inflating: esmini/EnvironmentSimulator/code-examples/image-capture/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/code-examples/image-capture/image-capture.cpp
#   inflating: esmini/EnvironmentSimulator/code-examples/image-capture/multiple-cameras.cpp
#    creating: esmini/EnvironmentSimulator/code-examples/init_with_string/
#   inflating: esmini/EnvironmentSimulator/code-examples/init_with_string/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/code-examples/init_with_string/init_with_string.cpp
#    creating: esmini/EnvironmentSimulator/code-examples/mixed_control/
#   inflating: esmini/EnvironmentSimulator/code-examples/mixed_control/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/code-examples/mixed_control/mixed_control.cpp
#   inflating: esmini/EnvironmentSimulator/code-examples/mixed_control/mixed_control.xosc
#    creating: esmini/EnvironmentSimulator/code-examples/osi-groundtruth-cs/
#   inflating: esmini/EnvironmentSimulator/code-examples/osi-groundtruth-cs/CMakeLists.txt
#   inflating: esmini/EnvironmentSimulator/code-examples/osi-groundtruth-cs/README.adoc
#   inflating: esmini/EnvironmentSimulator/code-examples/osi-groundtruth-cs/osi-gt.cs
#    creating: esmini/EnvironmentSimulator/code-examples/osi-groundtruth-cs/osi3/
#   inflating: esmini/EnvironmentSimulator/code-examples/osi-groundtruth-cs/osi3/OsiCommon.cs
# ...
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/OperatingSystem_test.dir/compiler_depend.ts
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/OperatingSystem_test.dir/depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/OperatingSystem_test.dir/flags.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/OperatingSystem_test.dir/link.txt
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/OperatingSystem_test.dir/cmake_clean.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/OperatingSystem_test.dir/DependInfo.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/OperatingSystem_test.dir/progress.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/OperatingSystem_test.dir/OperatingSystem_test.cpp.o.d
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/OperatingSystem_test.dir/OperatingSystem_test.cpp.o
#    creating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManager_test.dir/
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManager_test.dir/build.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManager_test.dir/compiler_depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManager_test.dir/compiler_depend.ts
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManager_test.dir/depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManager_test.dir/flags.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManager_test.dir/link.txt
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManager_test.dir/cmake_clean.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManager_test.dir/DependInfo.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManager_test.dir/progress.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManager_test.dir/RoadManager_test.cpp.o.d
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManager_test.dir/RoadManager_test.cpp.o
#    creating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngine_test.dir/
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngine_test.dir/build.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngine_test.dir/compiler_depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngine_test.dir/compiler_depend.ts
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngine_test.dir/depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngine_test.dir/flags.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngine_test.dir/link.txt
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngine_test.dir/cmake_clean.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngine_test.dir/DependInfo.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngine_test.dir/progress.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngine_test.dir/ScenarioEngine_test.cpp.o.d
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngine_test.dir/ScenarioEngine_test.cpp.o
#    creating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioPlayer_test.dir/
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioPlayer_test.dir/build.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioPlayer_test.dir/compiler_depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioPlayer_test.dir/compiler_depend.ts
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioPlayer_test.dir/depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioPlayer_test.dir/flags.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioPlayer_test.dir/link.txt
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioPlayer_test.dir/cmake_clean.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioPlayer_test.dir/DependInfo.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioPlayer_test.dir/progress.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioPlayer_test.dir/ScenarioPlayer_test.cpp.o.d
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioPlayer_test.dir/ScenarioPlayer_test.cpp.o
#    creating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/build.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/compiler_depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/compiler_depend.ts
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/flags.make
#    creating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/__/
#    creating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/__/Applications/
#    creating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/__/Applications/replayer/
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/__/Applications/replayer/Replay.cpp.o.d
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/__/Applications/replayer/Replay.cpp.o
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/link.txt
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/cmake_clean.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/DependInfo.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/progress.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/ScenarioEngineDll_test.cpp.o.d
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/ScenarioEngineDll_test.dir/ScenarioEngineDll_test.cpp.o
#    creating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManagerDll_test.dir/
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManagerDll_test.dir/build.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManagerDll_test.dir/compiler_depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManagerDll_test.dir/compiler_depend.ts
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManagerDll_test.dir/depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManagerDll_test.dir/flags.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManagerDll_test.dir/link.txt
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManagerDll_test.dir/cmake_clean.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManagerDll_test.dir/DependInfo.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManagerDll_test.dir/progress.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManagerDll_test.dir/RoadManagerDll_test.cpp.o.d
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/RoadManagerDll_test.dir/RoadManagerDll_test.cpp.o
#    creating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/CommonMini_test.dir/
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/CommonMini_test.dir/build.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/CommonMini_test.dir/compiler_depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/CommonMini_test.dir/compiler_depend.ts
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/CommonMini_test.dir/depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/CommonMini_test.dir/flags.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/CommonMini_test.dir/link.txt
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/CommonMini_test.dir/cmake_clean.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/CommonMini_test.dir/DependInfo.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/CommonMini_test.dir/progress.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/CommonMini_test.dir/CommonMini_test.cpp.o.d
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/CommonMini_test.dir/CommonMini_test.cpp.o
#    creating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRoute_test.dir/
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRoute_test.dir/build.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRoute_test.dir/compiler_depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRoute_test.dir/compiler_depend.ts
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRoute_test.dir/depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRoute_test.dir/flags.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRoute_test.dir/link.txt
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRoute_test.dir/cmake_clean.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRoute_test.dir/DependInfo.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRoute_test.dir/progress.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRoute_test.dir/FollowRoute_test.cpp.o.d
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRoute_test.dir/FollowRoute_test.cpp.o
#    creating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRouteController_test.dir/
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRouteController_test.dir/build.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRouteController_test.dir/compiler_depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRouteController_test.dir/compiler_depend.ts
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRouteController_test.dir/depend.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRouteController_test.dir/flags.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRouteController_test.dir/link.txt
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRouteController_test.dir/cmake_clean.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRouteController_test.dir/DependInfo.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRouteController_test.dir/progress.make
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRouteController_test.dir/FollowRouteController_test.cpp.o.d
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/FollowRouteController_test.dir/FollowRouteController_test.cpp.o
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/CMakeDirectoryInformation.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CMakeFiles/progress.marks
#   inflating: esmini/build/EnvironmentSimulator/Unittest/Makefile
#   inflating: esmini/build/EnvironmentSimulator/Unittest/cmake_install.cmake
#   inflating: esmini/build/EnvironmentSimulator/Unittest/OperatingSystem_test
#   inflating: esmini/build/EnvironmentSimulator/Unittest/RoadManager_test
#   inflating: esmini/build/EnvironmentSimulator/Unittest/ScenarioEngine_test
#   inflating: esmini/build/EnvironmentSimulator/Unittest/ScenarioPlayer_test
#   inflating: esmini/build/EnvironmentSimulator/Unittest/ScenarioEngineDll_test
#   inflating: esmini/build/EnvironmentSimulator/Unittest/RoadManagerDll_test
#   inflating: esmini/build/EnvironmentSimulator/Unittest/CommonMini_test
#   inflating: esmini/build/EnvironmentSimulator/Unittest/FollowRoute_test
#   inflating: esmini/build/EnvironmentSimulator/Unittest/FollowRouteController_test
#   inflating: esmini/build/EnvironmentSimulator/Makefile
#   inflating: esmini/build/EnvironmentSimulator/cmake_install.cmake
#   inflating: esmini/build/install_manifest.txt
#   inflating: esmini/build/CMakeCache.txt
#   inflating: esmini/build/Makefile
#   inflating: esmini/build/cmake_install.cmake
#   inflating: esmini/build/compile_commands.json
#    creating: esmini/bin/
#   inflating: esmini/bin/libesminiLib.so
#   inflating: esmini/bin/libesminiLib_static.a
#   inflating: esmini/bin/libesminiRMLib.so
#   inflating: esmini/bin/esmini
#   inflating: esmini/bin/esmini-dyn
#   inflating: esmini/bin/odrviewer
#   inflating: esmini/bin/odrplot
#   inflating: esmini/bin/replayer
#   inflating: esmini/bin/dat2csv
#   inflating: esmini/bin/osireceiver
#    creating: esmini/code-examples-bin/
#   inflating: esmini/code-examples-bin/libesminiLib.so
#   inflating: esmini/code-examples-bin/libesminiLib_static.a
#   inflating: esmini/code-examples-bin/libesminiRMLib.so
#   inflating: esmini/code-examples-bin/access-odr
#   inflating: esmini/code-examples-bin/ad_hoc_traffic
#   inflating: esmini/code-examples-bin/action_injection
#   inflating: esmini/code-examples-bin/dual_controllers
#   inflating: esmini/code-examples-bin/hw2_arguments
#   inflating: esmini/code-examples-bin/hw3_fetch_states
#   inflating: esmini/code-examples-bin/hw4_external_ego_control
#   inflating: esmini/code-examples-bin/hw5_control_controllers_enabled
#   inflating: esmini/code-examples-bin/hw6_control_controllers_disabled
#   inflating: esmini/code-examples-bin/hw7_ideal_sensors
#   inflating: esmini/code-examples-bin/hw8_collision_detection
#   inflating: esmini/code-examples-bin/speed_controller
#   inflating: esmini/code-examples-bin/hello_world_static
#   inflating: esmini/code-examples-bin/ideal-sensors
#   inflating: esmini/code-examples-bin/image-capture
#   inflating: esmini/code-examples-bin/multiple-cameras
#   inflating: esmini/code-examples-bin/init_with_string
#   inflating: esmini/code-examples-bin/mixed_control
#   inflating: esmini/code-examples-bin/osi-groundtruth
#   inflating: esmini/code-examples-bin/osi-traffic_command
#   inflating: esmini/code-examples-bin/parametric-init
#   inflating: esmini/code-examples-bin/override-bounding-box
#   inflating: esmini/code-examples-bin/position-mode
#   inflating: esmini/code-examples-bin/rm-basic
#   inflating: esmini/code-examples-bin/rm-se
#   inflating: esmini/code-examples-bin/test-driver
# finishing deferred symbolic links:
#   esmini/externals/osi/linux/lib-dyn/debug/libopen_simulation_interface.so -> libopen_simulation_interface.so.3.5.0
#   esmini/externals/osi/linux/lib-dyn/debug/libprotobufd.so -> libprotobufd.so.3.15.2.0
#   esmini/externals/osi/linux/lib-dyn/release/libopen_simulation_interface.so -> libopen_simulation_interface.so.3.5.0
#   esmini/externals/osi/linux/lib-dyn/release/libprotobuf.so -> libprotobuf.so.3.15.2.0

# %%
# !apt-get install -y xvfb x11-utils
# !pip install ultralytics
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 libxtst6 libxxf86dga1 x11-xkb-utils xfonts-base
#   xfonts-encodings xfonts-utils xserver-common
# Suggested packages:
#   mesa-utils
# The following NEW packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 libxtst6 libxxf86dga1 x11-utils x11-xkb-utils xfonts-base
#   xfonts-encodings xfonts-utils xserver-common xvfb
# 0 upgraded, 12 newly installed, 0 to remove and 49 not upgraded.
# Need to get 8,046 kB of archives.
# After this operation, 12.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.12 [28.7 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.12 [864 kB]
# Fetched 8,046 kB in 3s (2,723 kB/s)
# Selecting previously unselected package libfontenc1:amd64.
# (Reading database ... 123633 files and directories currently installed.)
# Preparing to unpack .../00-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../01-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../02-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../03-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../04-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../05-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../06-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../07-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../08-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../09-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../10-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.12_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../11-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.12_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# Collecting ultralytics
#   Downloading ultralytics-8.3.49-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.13-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.49-py3-none-any.whl (898 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 48.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.13-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.49 ultralytics-thop-2.0.13

# %%
import sys, os
# !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/xvfb -O ../xvfb
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'
# !cp -r /content/drive/MyDrive/xvfb /content/xvfb
# !chmod 755 /content/xvfb
# Out:
# Starting virtual X frame buffer: Xvfb.

# %%
# %rm -r sim_loop

# %%
# !/content/xvfb start
# %cd /content/esmini
# !chmod 755 bin/esmini
# %cd /content
# !git clone https://github.com/patrickw16/sim_loop.git
# Out:
# Starting virtual X frame buffer: Xvfb.
# /content/esmini
# /content
# Cloning into 'sim_loop'...
# remote: Enumerating objects: 368, done.
# remote: Counting objects: 100% (156/156), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 368 (delta 45), reused 124 (delta 20), pack-reused 212 (from 1)
# Receiving objects: 100% (368/368), 76.32 MiB | 15.16 MiB/s, done.
# Resolving deltas: 100% (46/46), done.

# %%
# !python /content/sim_loop/colab_execution.py --window 60 60 800 400 --headless --osc /content/sim_loop/scenarios/cut-in.xosc
# Out:
# esmini GIT REV: v2.40.3-0-9fa4bae8
# esmini GIT TAG: v2.40.3
# esmini GIT BRANCH: tags/v2.40.3^0
# esmini BUILD VERSION: N/A - client build
# Player arguments:  /content/sim_loop/colab_execution.py --window 60 60 800 400 --headless --osc /content/sim_loop/scenarios/cut-in.xosc
# esmini GIT REV: v2.40.3-0-9fa4bae8
# esmini GIT TAG: v2.40.3
# esmini GIT BRANCH: tags/v2.40.3^0
# esmini BUILD VERSION: N/A - client build
# No fixed timestep specified - running in realtime speed
# Generated seed 3853245699
# Loading /content/sim_loop/scenarios/cut-in.xosc (v1.1)
# 0 variables
# Unsupported geo reference attr: +no_defs
# Unsupported object type: rail-pole - interpret as NONE
# Unsupported object type: rail-pole - interpret as NONE
# Unsupported object type: guide-post - interpret as NONE
# Unsupported object type: guide-post - interpret as NONE
# Loaded OpenDRIVE: /content/esmini/resources/xodr/e6mini.xodr
# Expr ${250/3.6} = 250/3.6 = 69.4444444444
# Expr ${$EgoSpeed / 3.6} = 108 / 3.6 = 30.0000000000
# Expr ${$EgoStartS + $s_delta} = 25 + 20 = 45.0000000000
# Expr ${$EgoSpeed/3.6 - $v_delta/3.6} = 108/3.6 - 10/3.6 = 27.2222222222
# 6 parameters:
#    v_delta = 10
#    s_delta = 20
#    EgoSpeed = 108
#    EgoStartS = 25
#    TargetVehicle = car_red
#    HostVehicle = car_white
# 0.000: Window created at 60,60 with size 800,400
# 0.000: Loaded scenegraph: /content/esmini/resources/models/e6mini.osgb
# 0.000: Object ../models/railing-pole.osgb missing length, set to bounding box length 0.10
# 0.000: Object ../models/railing-pole.osgb missing width, set to bounding box width 0.10
# 0.000: Object ../models/railing-pole.osgb missing height, set to bounding box height 1.00
# 0.000: Object ../models/railing-pole.osgb missing length, set to bounding box length 0.10
# 0.000: Object ../models/railing-pole.osgb missing width, set to bounding box width 0.10
# 0.000: Object ../models/railing-pole.osgb missing height, set to bounding box height 1.00
# 0.000: Object ../models/railing.osgb missing length, set to bounding box length 4.00
# 0.000: Object ../models/railing.osgb missing width, set to bounding box width 0.10
# 0.000: Object ../models/railing.osgb missing height, set to bounding box height 0.20
# 0.000: Object ../models/railing.osgb missing length, set to bounding box length 4.00
# 0.000: Object ../models/railing.osgb missing width, set to bounding box width 0.10
# 0.000: Object ../models/railing.osgb missing height, set to bounding box height 0.20
# 0.000: Object ../models/guide-post.osgb missing length, set to bounding box length 0.08
# 0.000: Object ../models/guide-post.osgb missing width, set to bounding box width 0.13
# 0.000: Object ../models/guide-post.osgb missing height, set to bounding box height 1.25
# 0.000: Object ../models/guide-post.osgb missing length, set to bounding box length 0.08
# 0.000: Object ../models/guide-post.osgb missing width, set to bounding box width 0.13
# 0.000: Object ../models/guide-post.osgb missing height, set to bounding box height 1.25
# 0.000: Adjusted OverTaker bounding box to model car_red.osgb - xyz: 1.46, 0.00, 0.77 lwh: 5.04, 2.04, 1.49
# 0.000: Init Ego TeleportAction initState -> startTransition -> runningState
# 0.000: Starting teleport Action
# 0.000: Ego New position:
# 0.000: Pos(8.08, 24.97, -0.01) Rot(1.57, 0.00, 0.00) roadId 0 laneId -3 offset 0.00 t -8.00
# 0.000: Init Ego LongitudinalAction initState -> startTransition -> runningState
# 0.000: Init OverTaker TeleportAction initState -> startTransition -> runningState
# 0.000: Starting teleport Action
# 0.000: OverTaker New position:
# 0.000: Pos(4.58, 44.98, -0.03) Rot(1.57, 0.00, 0.00) roadId 0 laneId -2 offset 0.00 t -4.42
# 0.000: Init OverTaker LongitudinalAction initState -> startTransition -> runningState
# 0.000: storyBoard initState -> startTransition -> runningState
# 0.000: CutInAndBrakeStory initState -> startTransition -> runningState
# 0.000: CutInAndBrakeAct initState -> initToStandbyTransition -> standbyState
# 0.000: Init Ego TeleportAction runningState -> endTransition -> completeState
# 0.000: Init Ego LongitudinalAction runningState -> endTransition -> completeState
# 0.000: Init OverTaker TeleportAction runningState -> endTransition -> completeState
# 0.000: Init OverTaker LongitudinalAction runningState -> endTransition -> completeState
# 0.000: FetchCapturedImagePtr Error: No image data
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107FBE6CBE50>
#
# 0: 320x640 1 cars, 52.9ms
# Speed: 3.0ms preprocess, 52.9ms inference, 612.4ms postprocess per image at shape (1, 3, 320, 640)
# 0.100: Trigger /------------------------------------------------
# 0.100: CutInActStart == true, 0.1000 > 0.0000 edge: none
# 0.100: Trigger  ------------------------------------------------/
# 0.100: CutInAndBrakeAct standbyState -> startTransition -> runningState
# 0.100: CutInAndBrakeSequence initState -> startTransition -> runningState
# 0.100: CutInManeuver initState -> startTransition -> runningState
# 0.100: CutInEvent initState -> initToStandbyTransition -> standbyState
# 0.100: Trigger /------------------------------------------------
# 0.100: Trigger  ------------------------------------------------/
# 0.100: CutInEvent standbyState -> startTransition -> runningState
# 0.100: CutInAction initState -> startTransition -> runningState
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107FBE6CB310>
#
# 0: 320x640 1 cars, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810B0D0>
#
# 0: 320x640 1 cars, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F981B7F70>
#
# 0: 320x640 1 cars, 10.6ms
# Speed: 2.5ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F981B7F70>
#
# 0: 320x640 1 cars, 14.1ms
# Speed: 2.5ms preprocess, 14.1ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810B0D0>
#
# 0: 320x640 1 cars, 13.9ms
# Speed: 2.5ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810B0D0>
#
# 0: 320x640 1 cars, 14.3ms
# Speed: 2.3ms preprocess, 14.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F981B7F70>
#
# 0: 320x640 1 cars, 16.8ms
# Speed: 3.7ms preprocess, 16.8ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F981B7F70>
#
# 0: 320x640 1 cars, 26.8ms
# Speed: 4.2ms preprocess, 26.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810B0D0>
#
# 0: 320x640 1 cars, 13.6ms
# Speed: 7.2ms preprocess, 13.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810B0D0>
#
# 0: 320x640 1 cars, 12.1ms
# Speed: 10.6ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F981B7F70>
#
# 0: 320x640 1 cars, 14.1ms
# Speed: 2.5ms preprocess, 14.1ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F981B7F70>
#
# 0: 320x640 1 cars, 11.3ms
# Speed: 9.6ms preprocess, 11.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810B0D0>
#
# 0: 320x640 1 cars, 11.5ms
# Speed: 9.5ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810B0D0>
#
# 0: 320x640 1 cars, 31.9ms
# Speed: 3.0ms preprocess, 31.9ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F981B7F70>
#
# 0: 320x640 1 cars, 13.2ms
# Speed: 6.5ms preprocess, 13.2ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F981B7F70>
#
# 0: 320x640 1 cars, 11.2ms
# Speed: 2.4ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810B0D0>
#
# 0: 320x640 1 cars, 17.2ms
# Speed: 5.3ms preprocess, 17.2ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810B0D0>
#
# 0: 320x640 1 cars, 12.0ms
# Speed: 2.4ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F981B7F70>
#
# 0: 320x640 1 cars, 12.2ms
# Speed: 7.6ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F981B7F70>
#
# 0: 320x640 1 cars, 11.5ms
# Speed: 2.4ms preprocess, 11.5ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810B0D0>
#
# 0: 320x640 1 cars, 11.5ms
# Speed: 2.4ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810B0D0>
#
# 0: 320x640 1 cars, 11.8ms
# Speed: 10.7ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F981B7F70>
#
# 0: 320x640 1 cars, 30.0ms
# Speed: 2.4ms preprocess, 30.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F981B7F70>
#
# 0: 320x640 1 cars, 31.6ms
# Speed: 2.4ms preprocess, 31.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810B0D0>
#
# 0: 320x640 (no detections), 13.5ms
# Speed: 6.3ms preprocess, 13.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107FBE6968C0>
#
# 0: 320x640 1 cars, 34.7ms
# Speed: 2.3ms preprocess, 34.7ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 20.4ms
# Speed: 2.4ms preprocess, 20.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 1 cars, 27.0ms
# Speed: 2.5ms preprocess, 27.0ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 26.1ms
# Speed: 10.6ms preprocess, 26.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
# 3.000: CutInAction runningState -> endTransition -> completeState
# 3.000: CutInEvent complete after 1 execution
# 3.000: CutInEvent runningState -> endTransition -> completeState
# 3.000: CutInManeuver runningState -> endTransition -> completeState
# 3.000: CutInAndBrakeSequence complete after 1 execution
# 3.000: CutInAndBrakeSequence runningState -> endTransition -> completeState
# 3.000: CutInAndBrakeAct runningState -> endTransition -> completeState
# 3.000: CutInAndBrakeStory runningState -> endTransition -> completeState
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 1 cars, 35.3ms
# Speed: 4.6ms preprocess, 35.3ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# 3.100: StopCondition timer 3.00s started
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 1 cars, 28.1ms
# Speed: 8.5ms preprocess, 28.1ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 1 cars, 33.7ms
# Speed: 9.5ms preprocess, 33.7ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 1 cars, 31.5ms
# Speed: 3.5ms preprocess, 31.5ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 1 cars, 16.6ms
# Speed: 2.5ms preprocess, 16.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 1 cars, 20.7ms
# Speed: 2.5ms preprocess, 20.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 1 cars, 32.1ms
# Speed: 10.7ms preprocess, 32.1ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 12.0ms
# Speed: 2.5ms preprocess, 12.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 12.2ms
# Speed: 2.4ms preprocess, 12.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 11.1ms
# Speed: 10.6ms preprocess, 11.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 11.2ms
# Speed: 9.6ms preprocess, 11.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 11.2ms
# Speed: 8.5ms preprocess, 11.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 23.6ms
# Speed: 2.4ms preprocess, 23.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 25.5ms
# Speed: 4.1ms preprocess, 25.5ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 24.3ms
# Speed: 11.2ms preprocess, 24.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 16.2ms
# Speed: 8.6ms preprocess, 16.2ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 14.4ms
# Speed: 2.5ms preprocess, 14.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 13.3ms
# Speed: 5.4ms preprocess, 13.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 17.4ms
# Speed: 2.4ms preprocess, 17.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 24.9ms
# Speed: 3.3ms preprocess, 24.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 22.1ms
# Speed: 2.4ms preprocess, 22.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
# <PIL.Image.Image image mode=RGB size=800x400 at 0x107F9810A770>
#
# 0: 320x640 (no detections), 14.3ms
# Speed: 2.3ms preprocess, 14.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
# 5.400: Collision between Ego and OverTaker

# %%
# %mkdir logs

# %%
# prompt: move all log files to logs folder

import shutil
import glob

# Move all log files to the logs folder
log_files = glob.glob("*.txt")  # Find all files ending with .log in the current directory
for log_file in log_files:
  try:
    shutil.move(log_file, "logs/")  # Move the file to the logs/ directory
  except FileNotFoundError:
    print(f"Error: The 'logs' directory does not exist.")
  except shutil.Error as e:
    print(f"Error moving file {log_file}: {e}")

# %%
# prompt: zip the logs folder

import shutil
import os

def zip_logs():
  # Check if the logs directory exists
  if os.path.exists("logs"):
    try:
      shutil.make_archive("logs", "zip", "logs")
      print("Logs folder zipped successfully to logs.zip")
    except Exception as e:
      print(f"Error zipping logs folder: {e}")
  else:
    print("Error: logs folder not found.")

zip_logs()
# Out:
# Logs folder zipped successfully to logs.zip
